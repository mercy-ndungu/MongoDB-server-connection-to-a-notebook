# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 2.1 MB/s eta 0:00:00m eta 0:00:010:01:010m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 4.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...

# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np
from pprint import PrettyPrinter
